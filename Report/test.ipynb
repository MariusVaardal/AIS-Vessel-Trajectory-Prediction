# %%
feats_to_include = [
    feat 
    for i in range(3) 
    for feat in (
        f'prev_lat_{i}', 
        f'prev_lon_{i}', 
        f'prev_speed_{i}', 
        f'prev_course_{i}', 
        f'prev_rotation_{i}', 
        f'prev_heading_{i}', 
        f'time_diff_seconds_{i}'
    )
]

print(feats_to_include)
# Out:
# ['prev_lat_0', 'prev_lon_0', 'prev_speed_0', 'prev_course_0', 'prev_rotation_0', 'prev_heading_0', 'time_diff_seconds_0', 'prev_lat_1', 'prev_lon_1', 'prev_speed_1', 'prev_course_1', 'prev_rotation_1', 'prev_heading_1', 'time_diff_seconds_1', 'prev_lat_2', 'prev_lon_2', 'prev_speed_2', 'prev_course_2', 'prev_rotation_2', 'prev_heading_2', 'time_diff_seconds_2']

# %%
import pandas as pd
s = pd.Series()
s['halla'] = 1
s['halla1'] = 2
print(s)
# Out:
# halla     1
# halla1    2
# dtype: int64
